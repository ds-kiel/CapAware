# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
plt.rcParams["figure.dpi"] = 200
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42
fig_size = (16, 2)

# %%
DATASET_PATH = './data/CAU-4312-Fjord5G-handovers-processed.parquet.gzip'
df = pd.read_parquet(DATASET_PATH)
df.info(verbose=True, show_counts=True, memory_usage='deep')
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 9181668 entries, 2024-11-05 13:04:28 to 2025-03-01 12:59:59
# Data columns (total 7 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   lat       9181668 non-null  float32
#  1   lon       9181668 non-null  float32
#  2   lRsrp     9181668 non-null  float32
#  3   lSinr     9181668 non-null  float32
#  4   lCqi      9181668 non-null  float32
#  5   speedkmh  9181668 non-null  float32
#  6   Handover  9181668 non-null  float32
# dtypes: float32(7)
# memory usage: 315.2 MB

# %%
df.head()
# Out:
#                            lat        lon  lRsrp  lSinr  lCqi  speedkmh  \
# timestamp_router
# 2024-11-05 13:04:28  54.313305  10.133142  -84.0   12.0  10.0  0.714872
# 2024-11-05 13:04:29  54.313293  10.133119  -84.0   12.0  10.0  0.988968
# 2024-11-05 13:04:30  54.313293  10.133111  -84.0   11.0  14.0  0.405588
# 2024-11-05 13:04:31  54.313290  10.133104  -84.0   11.0  14.0  0.574120
# 2024-11-05 13:04:32  54.313286  10.133092  -84.0   11.0  14.0  2.687252
#
#                      Handover
# timestamp_router
# 2024-11-05 13:04:28       0.0
# 2024-11-05 13:04:29       0.0
# 2024-11-05 13:04:30       0.0
# 2024-11-05 13:04:31       0.0
# 2024-11-05 13:04:32       0.0

# %%
df.keys()
# Out:
# Index(['lat', 'lon', 'lRsrp', 'lSinr', 'lCqi', 'speedkmh', 'Handover'], dtype='str')

# %%
df['Handover'].value_counts()
# Out:
# Handover
# 0.0    9150948
# 1.0      30720
# Name: count, dtype: int64

# %%
df['Handover'].value_counts(normalize=True)
# Out:
# Handover
# 0.0    0.996654
# 1.0    0.003346
# Name: proportion, dtype: float64
